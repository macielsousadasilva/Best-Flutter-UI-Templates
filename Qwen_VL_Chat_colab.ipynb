# %% [markdown]
# <a href="https://colab.research.google.com/github/macielsousadasilva/Best-Flutter-UI-Templates/blob/master/Qwen_VL_Chat_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !wget https://raw.githubusercontent.com/camenduru/Qwen-VL-Chat-colab/main/app.py -O /content/app.py

# !pip install -q tiktoken transformers_stream_generator gradio==3.50.2 optimum auto-gptq huggingface_hub
# !pip install -q modelscope -f https://pypi.org/project/modelscope

# !python app.py --share
# Out:
# /content
# --2025-03-14 18:08:02--  https://raw.githubusercontent.com/camenduru/Qwen-VL-Chat-colab/main/app.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9816 (9.6K) [text/plain]
# Saving to: ‘/content/app.py’
#
# /content/app.py     100%[===================>]   9.59K  --.-KB/s    in 0s
#
# 2025-03-14 18:08:03 (83.1 MB/s) - ‘/content/app.py’ saved [9816/9816]
#
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 70.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 45.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.6/433.6 kB 25.3 MB/s eta 0:00:00
# ...
